# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
from env import github_token, github_username
import acquire as aqr
import prepare as prep
import explore as exp
import visual as vis

import json
import nltk

import matplotlib.pyplot as plt
import numpy as np
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jongarcia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Specify the file name where you want to save the list
file_name = "repo_processed.json"

# Load the REPOS list from the JSON file
with open(file_name, 'r') as file:
    repo_loaded = json.load(file)

# %%
repos_df = pd.DataFrame(repo_loaded)
repos_df
# Out:
#                                       repo language  \
# 0              AtsushiSakai/PythonRobotics   Python
# 1                kiloreux/awesome-robotics     None
# 2                    NxRLab/ModernRobotics   Python
# 3                mithi/robotics-coursework     None
# 4                   onlytailei/CppRobotics      C++
# ..                                     ...      ...
# 672                     CatchZeng/dingtalk       Go
# 673            1c7/Translate-Subtitle-File     None
# 674  landy22granatt/Kumpulan-Script-Termux   Python
# 675        cirosantilli/china-dictatorship     HTML
# 676                       gege-circle/home     None
#
#                                        readme_contents
# 0    <img src="https://github.com/AtsushiSakai/Pyth...
# 1    Awesome Robotics\n================\n\n[![Aweso...
# 2    # Modern Robotics:  Mechanics, Planning, and C...
# 3    # [🐳](https://mithi.github.io/deep-blueberry) ...
# 4    # CppRobotics\n\nThis is the cpp implementatio...
# ..                                                 ...
# 672  # dingtalk\n\n![Go](https://github.com/CatchZe...
# 673  ## 字幕组机翻小助手 - [视频演示](https://www.bilibili.com/...
# 674  pkg update && pkg upgrade\npkg install bash\np...
# 675  <style>\npre{ white-space:pre }\n#header,#cont...
# 676  _Language:_ **中文** | [English](./README_EN.md)...
#
# [677 rows x 3 columns]

# %%
# Define lists for additional and exclusionary words
extra_words = [
    'C++', 'Python', 'JavaScript', 'C', 'Java', 'TypeScript',
    'C#', 'Rust', 'Ruby', 'Kotlin', 'Julia', 'PHP', 'Swift',
    'Common Lisp', 'Scheme', 'Dart', 'Scala', 'Objective-C',
    'Lua', 'Prolog', 'ro'
]

exclude_words = []

# List of other technologies, not languages
non_languages = [
    "CMake", "Jupyter Notebook", "HTML", "Go", "Shell", "TeX", 
    "CMake", "Dockerfile", "OpenSCAD", "MQL5", "Vue", "Smali", 
    "RobotFramework", "Cuda", "SCSS"
]

# Define the list of acceptable languages
labeled_languages = ['C++', 'Python']

# Process the DataFrame 'repos_df' by applying text preprocessing, filtering, and language categorization
repos_df = prep.process_dataframe(repos_df, extra_words, exclude_words, 'lemmatize', labeled_languages, non_languages)

# Display the first few rows of the processed DataFrame
repos_df.head()

# NOTES
# Remove any word bigger than n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_contents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y602sZmlsZQ%3D%3D?line=18'>19</a> labeled_languages = ['C++', 'Python']
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y602sZmlsZQ%3D%3D?line=20'>21</a> # Process the DataFrame 'repos_df' by applying text preprocessing, filtering, and language categorization
# ---> <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y602sZmlsZQ%3D%3D?line=21'>22</a> repos_df = prep.process_dataframe(repos_df, extra_words, exclude_words, 'lemmatize', labeled_languages, non_languages)
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y602sZmlsZQ%3D%3D?line=23'>24</a> # Display the first few rows of the processed DataFrame
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y602sZmlsZQ%3D%3D?line=24'>25</a> repos_df.head()
#
# File ~/codeup-data-science/github_nlp_project/prepare.py:277, in process_dataframe(df, extra_words, exclude_words, method, labeled_languages, non_languages)
#     262 """
#     263 Process a DataFrame by applying text preprocessing, filtering, and language categorization operations.
#     264
#    (...)
#     274     pd.DataFrame: The processed DataFrame with rows removed based on non-language items.
#     275 """
#     276 # Preprocess the 'text' column
# --> 277 df = preprocess_text_column(df, extra_words, exclude_words, method)
#     279 # Remove rows with invalid data
#     280 df = remove_invalid_rows(df)
#
# File ~/codeup-data-science/github_nlp_project/prepare.py:188, in preprocess_text_column(df, extra_words, exclude_words, method)
#     175 """
#     176 Preprocess the 'text' column of a DataFrame by applying text cleaning and processing steps.
#     177
#    (...)
#     185     None: The function modifies the DataFrame 'df' in place.
#     186 """
#     187 # Apply basic cleaning and tokenization to 'text_contents' column
# --> 188 df['text'] = df['text_contents'].apply(basic_clean).apply(tokenize)
#     190 # Drop the 'text_contents' column
#     191 df.drop(columns='text_contents', axis=1, inplace=True)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'text_contents'

# %%
repos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541 entries, 0 to 674
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   repo      541 non-null    object
#  1   language  541 non-null    object
#  2   readme    541 non-null    object
# dtypes: object(3)
# memory usage: 16.9+ KB

# %%
import nltk
from collections import Counter

def process_text(row, n, top_n):
    # Split the text string on each space to get individual words
    word_list = row.split()
    
    # Generate the n-grams
    n_grams = list(nltk.ngrams(word_list, n))
    
    # Join the words in the n-grams
    n_grams_joined = ['_'.join(gram) for gram in n_grams]
    
    # Calculate the frequency of each n-gram
    n_gram_counts = Counter(n_grams_joined)
    
    # Get the top n n-grams
    top_n_grams = [item[0] for item in n_gram_counts.most_common(top_n)]
    
    return ' '.join(top_n_grams)

# %%
# Number of words in each n-gram and number of top n-grams to retain
n = 2  # for trigrams
top_n = 20  # for example, adjust as needed

# Process the 'readme' column and store the result in a new 'top_trigrams' column
repos_df.loc[:, 'bigrams'] = repos_df['readme'].apply(lambda x: process_text(x, n, top_n))

# %%
# Number of words in each n-gram and number of top n-grams to retain
n = 3  # for trigrams
top_n = 20  # for example, adjust as needed

# Process the 'readme' column and store the result in a new 'top_trigrams' column
repos_df.loc[:, 'trigrams'] = repos_df['readme'].apply(lambda x: process_text(x, n, top_n))

# %%
repos_df.head()
# Out:
#                               repo language  \
# 0      AtsushiSakai/PythonRobotics   Python
# 2            NxRLab/ModernRobotics   Python
# 4           onlytailei/CppRobotics      C++
# 5         JdeRobot/RoboticsAcademy    Other
# 6  pptacher/probabilistic_robotics      C++
#
#                                               readme  \
# 0  pythonrobotics githubactionlinuxci githubactio...
# 2  modern robotics mechanic planning control code...
# 4  cpprobotics cpp implementation pythonrobotics ...
# 5  roboticsacademy learn robotics artificial inte...
# 6  probabilisticrobotics working detailed solutio...
#
#                                              bigrams  \
# 0  path_planning grid_based path_tracking steerin...
# 2  modern_robotics robotics_mechanic mechanic_pla...
# 4  red_circle black_line steering_control point_r...
# 5  learn_robotics mini_radi roboticsacademy_learn...
# 6  probabilistic_robotics victoria_park park_data...
#
#                                             trigrams
# 0  pythonroboticsfigure1png_master_atsushisakaipy...
# 2  modern_robotics_mechanic robotics_mechanic_pla...
# 4  speed_steering_control black_line_planned line...
# 5  roboticsacademy_learn_robotics learn_robotics_...
# 6  victoria_park_dataset probabilisticrobotics_wo...

# %%
repos_df.trigrams[0]
# Out:
# 'pythonroboticsfigure1png_master_atsushisakaipythonrobotics speed_steering_control 2d_grid_based path_tracking_simulation dynamic_window_approach based_path_planning algorithm_2d_grid control_path_tracking iterative_closest_point potential_field_algorithm grid_based_coverage based_coverage_path coverage_path_planning state_lattice_planning lqr_based_path rear_wheel_feedback lqr_speed_steering model_predictive_speed predictive_speed_steering model_predictive_control'

# %%
repos_df[repos_df['readme'] == 'packagesmainreadmerst']
# Out:
#                       repo language                 readme bi-grams
# 251  robocorp/rpaframework   Python  packagesmainreadmerst

# %%
repos_df.index[251]
# Out:
# 320

# %%
repos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 543 entries, 0 to 674
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   repo      543 non-null    object
#  1   language  543 non-null    object
#  2   readme    543 non-null    object
#  3   bi-grams  543 non-null    object
# dtypes: object(4)
# memory usage: 21.2+ KB

# %%
repos_df[repos_df['bi-grams'].isna()]
# Out:
# Empty DataFrame
# Columns: [repo, language, readme, bi-grams]
# Index: []

# %%
repos_df.to_csv('processed_repos.csv')

# %%
# Counts and ratios of language labels in a DataFrame
counts = exp.counts_and_ratios(repos_df, "language")
counts
# Out:
#             n   percent
# language
# C++       207  0.381215
# Python    201  0.370166
# Other     135  0.248619

# %%
cpp_freq_df, python_freq_df, other_freq_df, all_freq_df = exp.freq_to_dataframe(repos_df)

# %%
cpp_freq_df
# Out:
#                                          C++  count
# 0                                      build   1260
# 1                                      robot    930
# 2                                     status    643
# 3                                    install    637
# 4                                        use    602
# ...                                      ...    ...
# 17022                               prepared      1
# 17023                            masksavedir      1
# 17024                              competing      1
# 17025                          substantially      1
# 17026  cppcoreguidelinesinterfacesglobalinit      1
#
# [17027 rows x 2 columns]

# %%
# Calculate word frequencies for the top words with word column and index starting at 1
top_word_counts = exp.word_counts(repos_df)

# Display the top word frequencies
top_word_counts.head()
# Out:
#       word   all   C++  Python  Other
# 1    robot  2423   930    1088    405
# 2  install  1679   637     760    282
# 3    build  1657  1260     178    219
# 4    paper  1639   111    1494     34
# 5      use  1561   602     578    381

# %%
# Concatenate word frequency DataFrames with word column and index starting at 1
top_freq_df = exp.counts_df_concat(repos_df)

# Display top words per language side by side
top_freq_df.head(50)
# Out:
#               All  count                C++   count              Python  \
# 1           robot   2423              build  1260.0               paper
# 2         install   1679              robot   930.0               robot
# 3           build   1657             status   643.0               arxiv
# 4           paper   1639            install   637.0              python
# 5             use   1561                use   602.0             install
# 6           using   1472              using   580.0              object
# 7             run   1307               file   520.0            learning
# 8            code   1190            package   507.0         environment
# 9          python   1147                run   500.0               using
# 10           file   1123             system   488.0               model
# 11        example   1012            library   457.0                  3d
# 12          model   1005                  c   435.0                 use
# 13         object    978            example   408.0               point
# 14    environment    966               code   399.0                 run
# 15           data    937             source   395.0                code
# 16          point    933               data   376.0               image
# 17       learning    877             sensor   360.0                bash
# 18        library    858                 cd   347.0             example
# 19          arxiv    834             please   330.0                file
# 20        project    833               make   325.0           detection
# 21         system    824              cmake   325.0            training
# 22        package    821            control   322.0                data
# 23            see    798              point   320.0                test
# 24         status    794                map   315.0                 see
# 25        version    784                see   315.0                task
# 26             3d    783               used   312.0               cloud
# 27        control    767          following   298.0                 pip
# 28          image    759             python   296.0              please
# 29         please    758              model   284.0                  cd
# 30           bash    742            version   277.0                 set
# 31            set    705                set   276.0             network
# 32           also    696               also   273.0                also
# 33         source    689            project   267.0             control
# 34             cd    686            support   265.0             dataset
# 35      following    679            license   258.0                pose
# 36           test    678           robotics   254.0             project
# 37        support    669               test   243.0             version
# 38           used    664               need   239.0             library
# 39       robotics    656              frame   239.0              google
# 40           make    652        environment   234.0      heavycheckmark
# 41              c    632               work   233.0           following
# 42        license    627               bash   232.0              method
# 43            new    600              state   231.0           framework
# 44           work    585               note   225.0          estimation
# 45        command    578          parameter   223.0                used
# 46         sensor    569               sudo   219.0                work
# 47           need    562            command   219.0            robotics
# 48         method    544               type   217.0        installation
# 49      detection    540            default   216.0                deep
# 50     repository    530      documentation   212.0               agent
#
#      count           Other  count
# 1   1494.0           robot  405.0
# 2   1088.0             use  381.0
# 3    806.0         project  284.0
# 4    778.0         install  282.0
# 5    760.0            code  279.0
# 6    736.0             run  258.0
# 7    725.0           using  252.0
# 8    656.0         version  227.0
# 9    640.0           build  219.0
# 10   599.0         support  208.0
# 11   594.0            data  206.0
# 12   578.0            file  203.0
# 13   563.0         example  202.0
# 14   549.0         license  194.0
# 15   512.0             new  194.0
# 16   443.0        robotics  174.0
# 17   406.0             see  170.0
# 18   402.0            type  164.0
# 19   400.0          device  162.0
# 20   394.0            open  160.0
# 21   387.0             get  159.0
# 22   355.0             api  153.0
# 23   337.0         control  153.0
# 24   313.0        software  153.0
# 25   310.0            user  153.0
# 26   306.0          change  152.0
# 27   301.0         command  150.0
# 28   300.0         message  146.0
# 29   298.0          system  145.0
# 30   297.0               x  144.0
# 31   295.0           added  141.0
# 32   294.0              us  141.0
# 33   292.0          method  137.0
# 34   288.0              ha  136.0
# 35   285.0           image  135.0
# 36   282.0          source  135.0
# 37   280.0           block  134.0
# 38   275.0            need  133.0
# 39   273.0             set  132.0
# 40   268.0            make  130.0
# 41   264.0            also  129.0
# 42   255.0            mode  129.0
# 43   244.0             npm  128.0
# 44   241.0          please  128.0
# 45   239.0         library  126.0
# 46   236.0          github  125.0
# 47   228.0      repository  125.0
# 48   228.0           model  122.0
# 49   228.0      javascript  120.0
# 50   221.0       following  117.0

# %%
# Word frequencies, keeping words as the index
# The word frequencies will be stored in the 'word_counts' variable
word_counts = exp.word_counts(repos_df, reset_index=False)

# Display the first 5 rows
word_counts.head()

# I ran word_counts again because we need to set reset_index=False before using plot_top_words plot
# Out:
#           all   C++  Python  Other
# robot    2423   930    1088    405
# install  1679   637     760    282
# build    1657  1260     178    219
# paper    1639   111    1494     34
# use      1561   602     578    381

# %%
# Plot the top 20 words using a horizontal stacked bar chart

vis.plot_top_words(word_counts, column='all', top_n=50, figsize=(12, 12))

# %%
# Plot the top 20 words for C++ using a horizontal stacked bar chart
vis.plot_top_words(word_counts, column='C++', top_n=20, figsize=(12, 8), title= 'The 20 most common words in C++ repos and their ratios')

# %%
# Generate and display word clouds for different language sets
vis.word_clouds(repos_df)

# %%
cpp_text, python_text, other_text, all_text = exp.join_text(repos_df)
cpp_words, python_words, other_words, all_words = exp.list_words(repos_df)
cpp_freq, python_freq, other_freq, all_freq = exp.word_freq(repos_df)

# %%
type(cpp_words)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## No functions have been created for the work below

# %%
cpp_ratio_words = vis.calculate_ratios(repos_df, min_count_cpp=100, min_count_python=100, min_count_other=100, sort_column='p_C++')
cpp_ratio_words
# Out:
#           all   C++  Python  Other  p_C++  p_Python  p_Other
# build    1657  1260     178    219   76.0      11.0     13.0
# sensor    569   360     105    104   63.0      18.0     18.0
# package   821   507     214    100   62.0      26.0     12.0
# system    824   488     191    145   59.0      23.0     18.0
# source    689   395     159    135   57.0      23.0     20.0
# get       424   121     144    159   29.0      34.0     38.0
# model    1005   284     599    122   28.0      60.0     12.0
# method    544   152     255    137   28.0      47.0     25.0
# api       419   111     155    153   26.0      37.0     37.0
# image     759   181     443    135   24.0      58.0     18.0

# %%
# Plot the top 20 words for C++ using a horizontal stacked bar chart
vis.plot_top_words(cpp_ratio_words, column='C++', top_n=10, figsize=(12, 8))

# %%
top_20_cpp_bigrams = exp.get_top_n_bigrams(python_words, 2, top_n= 20, remove_delimiter=True)
top_20_cpp_bigrams
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y220sZmlsZQ%3D%3D?line=0'>1</a> top_20_cpp_bigrams = exp.get_top_n_bigrams(python_words, 2, top_n= 20, remove_delimiter=True)
#       <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y220sZmlsZQ%3D%3D?line=1'>2</a> top_20_cpp_bigrams
#
# AttributeError: module 'explore' has no attribute 'get_top_n_bigrams'

# %%
top_20_cpp_bigrams = exp.get_top_n_bigrams(python_words, 2, top_n= 20, remove_delimiter=True)
top_20_cpp_bigrams
# Out:
# (paper, arxiv)                      632
# (point, cloud)                      299
# (object, detection)                 248
# (pip, install)                      233
# (reinforcement, learning)           185
# (3d, object)                        177
# (heavycheckmark, heavycheckmark)    175
# (bicubic, google)                   160
# (paper, code)                       152
# (pose, estimation)                  128
# (git, clone)                        122
# (detection, paper)                  107
# (robot, framework)                   96
# (cloud, paper)                       89
# (estimation, paper)                  80
# (object, pose)                       77
# (deep, learning)                     74
# (bash, python)                       66
# (make, sure)                         66
# (3d, point)                          65
# Name: count, dtype: int64

# %%
import nltk
import pandas as pd

def get_top_n_ngrams(series, num_words, top_n, remove_delimiter=False):
    """
    Get the top N n-grams from a Series of text data.

    Parameters:
    series (Series): A Series containing text data.
    num_words (int): The number of words to consider for creating n-grams.
    top_n (int): The number of top n-grams to retrieve.
    remove_delimiter (bool): Whether to remove delimiters from the n-grams. Defaults to False.

    Returns:
    Series: A Series with the top N n-grams and their counts.
    """
    # Create n-grams directly from the input series
    ngrams = list(nltk.ngrams(series, num_words))

    if remove_delimiter:
        # Remove delimiters from n-grams by joining without commas
        ngrams = [tuple(" ".join(word.split(",")) for word in ngram) for ngram in ngrams]

    # Create a Series of n-gram counts and retrieve the top N n-grams
    top_ngrams = (pd.Series(ngrams)
                  .value_counts()
                  .head(top_n))

    # Display n-grams without commas
    top_ngrams.index = [' '.join(ngram) for ngram in top_ngrams.index]

    return top_ngrams

# Test the updated function with bigrams and display without commas
top_20_cpp_bigrams = get_top_n_ngrams(python_words, 2, top_n=20, remove_delimiter=False)
print(top_20_cpp_bigrams)
# Out:
# paper arxiv                      632
# point cloud                      299
# object detection                 248
# pip install                      233
# reinforcement learning           185
# 3d object                        177
# heavycheckmark heavycheckmark    175
# bicubic google                   160
# paper code                       152
# pose estimation                  128
# git clone                        122
# detection paper                  107
# robot framework                   96
# cloud paper                       89
# estimation paper                  80
# object pose                       77
# deep learning                     74
# bash python                       66
# make sure                         66
# 3d point                          65
# Name: count, dtype: int64

# %%
import nltk
import pandas as pd

def get_top_n_ngrams(series, num_words, top_n, remove_delimiter=False):
    """
    Get the top N n-grams from a Series of text data.

    Parameters:
    series (Series): A Series containing text data.
    num_words (int): The number of words to consider for creating n-grams.
    top_n (int): The number of top n-grams to retrieve.
    remove_delimiter (bool): Whether to remove delimiters from the n-grams. Defaults to False.

    Returns:
    Series: A Series with the top N n-grams and their counts.
    """
    # Create n-grams directly from the input series
    ngrams = list(nltk.ngrams(series, num_words))

    # if remove_delimiter:
    #     # Remove delimiters from n-grams by joining without commas
    #     ngrams = [tuple(" ".join(word.split(",")) for word in ngram) for ngram in ngrams]

    # Create a Series of n-gram counts and retrieve the top N n-grams
    top_ngrams = (pd.Series(ngrams)
                  .value_counts()
                  .head(top_n))

    if remove_delimiter:
        # If remove_delimiter is True, join the words in the n-grams and remove delimiters
        top_ngrams.index = [' '.join(gram) for gram in top_ngrams.index]

    return top_ngrams

# Test the updated function with bigrams and display without commas
top_20_cpp_bigrams = get_top_n_ngrams(python_words, 2, top_n=20, remove_delimiter=False)
print(top_20_cpp_bigrams)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb Cell 22 line 3
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y234sZmlsZQ%3D%3D?line=32'>33</a>     return top_ngrams
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y234sZmlsZQ%3D%3D?line=34'>35</a> # Test the updated function with bigrams and display without commas
# ---> <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y234sZmlsZQ%3D%3D?line=35'>36</a> top_20_cpp_bigrams = get_top_n_ngrams(python_words, 2, top_n=20, remove_delimiter=False)
#      <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/github_nlp_project/explore.ipynb#Y234sZmlsZQ%3D%3D?line=36'>37</a> print(top_20_cpp_bigrams)
#
# NameError: name 'python_words' is not defined

# %%
# Test the updated function with bigrams and display without commas
top_20_cpp_bigrams = get_top_n_ngrams(python_words, 3, top_n=20, remove_delimiter=False)
print(top_20_cpp_bigrams)
# Out:
# 3d object detection                             130
# heavycheckmark heavycheckmark heavycheckmark    122
# object detection paper                           89
# point cloud paper                                89
# 224 0875 bicubic                                 65
# 0875 bicubic google                              65
# git clone cd                                     61
# 3d point cloud                                   58
# detection paper arxiv                            56
# 10 bicubic google                                53
# object pose estimation                           52
# deep reinforcement learning                      51
# estimation paper arxiv                           49
# pose estimation paper                            47
# cloud paper arxiv                                44
# pip install e                                    43
# 6d object pose                                   43
# paper code arxiv                                 42
# sudo aptget install                              38
# pip install r                                    36
# Name: count, dtype: int64

# %%
top_20_cpp_bigrams.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 20 entries, ('paper', 'arxiv') to ('3d', 'point')
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 20 non-null     int64
# dtypes: int64(1)
# memory usage: 876.0+ bytes

# %%
vis.plot_ngrams(top_20_cpp_bigrams, top_n=20, figsize=(12, 6), title=None)
