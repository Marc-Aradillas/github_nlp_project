# %%
import acquire as a
import re

# %% [markdown]
# # acquire

# %%
url = "https://github.com/search?q=robotics+stars%3A%3E200&type=repositories&p=1"

# %%
repos = a.github_api_request(url)
repos
# Out:
# {'payload': {'header_redesign_enabled': False,
#   'results': [{'id': '54376220',
#     'archived': False,
#     'color': '#3572A5',
#     'followers': 19992,
#     'has_funding_file': True,
#     'hl_name': 'AtsushiSakai/Python<em>Robotics</em>',
#     'hl_trunc_description': 'Python sample codes for <em>robotics</em> algorithms.',
#     'language': 'Python',
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 54376220,
#       'name': 'PythonRobotics',
#       'owner_id': 3813847,
#       'owner_login': 'AtsushiSakai',
#       'updated_at': '2023-10-18T13:02:18.783Z',
#       'has_issues': True}},
#     'sponsorable': True,
#     'topics': ['slam',
#      'robotics',
#      'localization',
#      'python',
#      'mapping',
#      'control',
#      'algorithm',
#      'robot',
#      'animation',
#      'path-planning',
#      'autonomous-driving',
#      'autonomous-vehicles',
#      'ekf',
#      'hacktoberfest',
#      'cvxpy',
#      'autonomous-navigation'],
#     'type': 'Public',
#     'help_wanted_issues_count': 4,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '46938122',
#     'archived': False,
#     'color': None,
#     'followers': 3543,
#     'has_funding_file': False,
#     'hl_name': 'kiloreux/awesome-<em>robotics</em>',
#     'hl_trunc_description': 'A list of awesome <em>Robotics</em> resources',
#     'language': None,
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 46938122,
#       'name': 'awesome-robotics',
#       'owner_id': 6282557,
#       'owner_login': 'kiloreux',
#       'updated_at': '2023-08-29T16:43:56.673Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['robotics'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '69972442',
#     'archived': False,
#     'color': '#3572A5',
#     'followers': 1580,
#     'has_funding_file': False,
#     'hl_name': 'NxRLab/Modern<em>Robotics</em>',
#     'hl_trunc_description': 'Modern <em>Robotics</em>: Mechanics, Planning, and Control Code Library --- The primary purpose of the provided software is to be easy to read and…',
#     'language': 'Python',
#     'mirror': False,
#     'owned_by_organization': True,
#     'public': True,
#     'repo': {'repository': {'id': 69972442,
#       'name': 'ModernRobotics',
#       'owner_id': 3316069,
#       'owner_login': 'NxRLab',
#       'updated_at': '2023-02-03T02:06:40.795Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': [],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '95303580',
#     'archived': False,
#     'color': None,
#     'followers': 2319,
#     'has_funding_file': False,
#     'hl_name': 'mithi/<em>robotics</em>-coursework',
#     'hl_trunc_description': '🤖 Places where you can learn <em>robotics</em> (and stuff like that) online 🤖',
#     'language': None,
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 95303580,
#       'name': 'robotics-coursework',
#       'owner_id': 1670421,
#       'owner_login': 'mithi',
#       'updated_at': '2021-11-20T19:46:35.713Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['robotics',
#      'ros',
#      'computer-science',
#      'learning',
#      'udacity',
#      'algorithm',
#      'university',
#      'algorithms',
#      'coursera',
#      'edx',
#      'self-learning',
#      'moocs'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '178146605',
#     'archived': False,
#     'color': '#f34b7d',
#     'followers': 1503,
#     'has_funding_file': False,
#     'hl_name': 'onlytailei/Cpp<em>Robotics</em>',
#     'hl_trunc_description': 'cpp implementation of <em>robotics</em> algorithms including localization, mapping, SLAM, path planning and control',
#     'language': 'C++',
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 178146605,
#       'name': 'CppRobotics',
#       'owner_id': 7247925,
#       'owner_login': 'onlytailei',
#       'updated_at': '2023-07-15T13:38:33.921Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['localization', 'algorithms', 'cpp', 'robotics', 'planning'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '39567107',
#     'archived': False,
#     'color': '#f1e05a',
#     'followers': 249,
#     'has_funding_file': False,
#     'hl_name': 'JdeRobot/<em>Robotics</em>Academy',
#     'hl_trunc_description': 'Learn <em>Robotics</em> with JdeRobot',
#     'language': 'JavaScript',
#     'mirror': False,
#     'owned_by_organization': True,
#     'public': True,
#     'repo': {'repository': {'id': 39567107,
#       'name': 'RoboticsAcademy',
#       'owner_id': 10959337,
#       'owner_login': 'JdeRobot',
#       'updated_at': '2023-10-19T13:27:13.084Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['computer-vision',
#      'robotics',
#      'ros',
#      'gazebo',
#      'robotics-programming'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '132924793',
#     'archived': False,
#     'color': '#f34b7d',
#     'followers': 1120,
#     'has_funding_file': True,
#     'hl_name': 'pptacher/probabilistic_<em>robotics</em>',
#     'hl_trunc_description': 'solution of exercises of the book "probabilistic <em>robotics</em>"',
#     'language': 'C++',
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 132924793,
#       'name': 'probabilistic_robotics',
#       'owner_id': 37937922,
#       'owner_login': 'pptacher',
#       'updated_at': '2023-05-18T06:43:16.038Z',
#       'has_issues': True}},
#     'sponsorable': True,
#     'topics': ['c-plus-plus',
#      'cpp',
#      'robotics',
#      'navigation',
#      'julia',
#      'numpy',
#      'matlab',
#      'particle-filter',
#      'bayesian-inference',
#      'lapack',
#      'slam',
#      'google-cloud-platform',
#      'autonomous-vehicles',
#      'seif',
#      'kalman-filter',
#      'probabilistic-robotics',
#      'armadillo-library',
#      'fastslam',
#      'intel-mkl-library',
#      'victoria-park-dataset'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '56404753',
#     'archived': False,
#     'color': None,
#     'followers': 1951,
#     'has_funding_file': False,
#     'hl_name': 'jslee02/awesome-<em>robotics</em>-libraries',
#     'hl_trunc_description': '😎 A curated list of <em>robotics</em> libraries and software',
#     'language': None,
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 56404753,
#       'name': 'awesome-robotics-libraries',
#       'owner_id': 4038467,
#       'owner_login': 'jslee02',
#       'updated_at': '2023-10-18T08:50:53.992Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['machine-learning',
#      'robotics',
#      'simulation',
#      'optimization',
#      'motion-planning',
#      'awesome-list',
#      'slam',
#      'robotics-libraries',
#      'multibody-dynamics'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '33467565',
#     'archived': False,
#     'color': '#3572A5',
#     'followers': 1579,
#     'has_funding_file': False,
#     'hl_name': 'petercorke/<em>robotics</em>-toolbox-python',
#     'hl_trunc_description': '<em>Robotics</em> Toolbox for Python',
#     'language': 'Python',
#     'mirror': False,
#     'owned_by_organization': False,
#     'public': True,
#     'repo': {'repository': {'id': 33467565,
#       'name': 'robotics-toolbox-python',
#       'owner_id': 11801682,
#       'owner_login': 'petercorke',
#       'updated_at': '2023-10-16T10:16:08.554Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['robotics',
#      'python',
#      'kinematics',
#      'dynamics',
#      'motion-planning',
#      'trajectory-generation',
#      'jacobian',
#      'hessian',
#      'robotics-control',
#      'robotics-simulation',
#      'robotics-toolbox',
#      'robot-manipulator'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False},
#    {'id': '298347380',
#     'archived': False,
#     'color': '#178600',
#     'followers': 1694,
#     'has_funding_file': False,
#     'hl_name': 'Unity-Technologies/Unity-<em>Robotics</em>-Hub',
#     'hl_trunc_description': 'Central repository for tools, tutorials, resources, and documentation for <em>robotics</em> simulation in Unity.',
#     'language': 'C#',
#     'mirror': False,
#     'owned_by_organization': True,
#     'public': True,
#     'repo': {'repository': {'id': 298347380,
#       'name': 'Unity-Robotics-Hub',
#       'owner_id': 426196,
#       'owner_login': 'Unity-Technologies',
#       'updated_at': '2023-10-03T16:35:40.307Z',
#       'has_issues': True}},
#     'sponsorable': False,
#     'topics': ['ros',
#      'simulation',
#      'physics-simulation',
#      'robot',
#      'unity',
#      'tutorials',
#      'motion-planning',
#      'planning',
#      'trajectory-generation',
#      'manipulation',
#      'urdf',
#      'robotics-control',
#      'physics-3d',
#      'autonomy',
#      'robotics-simulation',
#      'autonomous-robots',
#      'robot-simulation',
#      'robot-manipulator',
#      'unity-robotics',
#      'robotics-development'],
#     'type': 'Public',
#     'help_wanted_issues_count': 0,
#     'good_first_issue_issues_count': 0,
#     'starred_by_current_user': False}],
#   'type': 'repositories',
#   'page': 1,
#   'page_count': 68,
#   'elapsed_millis': 263,
#   'errors': [],
#   'result_count': 677,
#   'facets': [{'kind': 'FACET_KIND_LANGUAGE',
#     'entries': [{'name': 'C++',
#       'language_color': '#f34b7d',
#       'query': 'language:C++'},
#      {'name': 'Python',
#       'language_color': '#3572A5',
#       'query': 'language:Python'},
#      {'name': 'JavaScript',
#       'language_color': '#f1e05a',
#       'query': 'language:JavaScript'},
#      {'name': 'C', 'language_color': '#555555', 'query': 'language:C'},
#      {'name': 'Jupyter Notebook',
#       'language_color': '#DA5B0B',
#       'query': 'language:Jupyter Notebook'},
#      {'name': 'Java', 'language_color': '#b07219', 'query': 'language:Java'},
#      {'name': 'TypeScript',
#       'language_color': '#3178c6',
#       'query': 'language:TypeScript'},
#      {'name': 'C#', 'language_color': '#178600', 'query': 'language:C#'},
#      {'name': 'Go', 'language_color': '#00ADD8', 'query': 'language:Go'},
#      {'name': 'HTML',
#       'language_color': '#e34c26',
#       'query': 'language:HTML'}]}],
#   'protected_org_logins': [],
#   'topics': None,
#   'query_id': '',
#   'logged_in': False,
#   'sign_up_path': '/signup?source=code_search_results',
#   'sign_in_path': '/login?return_to=https%3A%2F%2Fgithub.com%2Fsearch%3Fq%3Drobotics%2Bstars%253A%253E200%26type%3Drepositories%26p%3D1',
#   'metadata': None,
#   'csrf_tokens': {'/AtsushiSakai/PythonRobotics/star': {'post': 'RATOcx1pLyrgzcotn2YNB6xxrtVtU6VyV47KyCKHYNtZ5GtEui8xwyN6RSD3k1lHYKngdiDKjOAkMdEqEBPeqw'},
#    '/AtsushiSakai/PythonRobotics/unstar': {'post': '0XKGn-tiqq4D4q_aiiKiV6oOsiU3UMBWRcQvZ5gB6QNeQgnheb1_11rn_QEXllFOnrgMpDsBQGXq9X5S8F-5Nw'},
#    '/kiloreux/awesome-robotics/star': {'post': 'h9Sw0jx3t1QA9QutUGGXoTqQL3DpuwWdI0DfWboYVsQc90lu4fkrXaN-2GSAUBAU1JZW7CEfq56ZBa-RJSNcrw'},
#    '/kiloreux/awesome-robotics/unstar': {'post': 'OL1y10IWJzpl1jUKS81GlF4NvXqscZP9RfMMS8l1N-Bx_fQv7RWQ8sC2WfwnXtK_nNosXmo7UcUImgOcW9oxHg'},
#    '/NxRLab/ModernRobotics/star': {'post': 'pwQG52kScABSuXb4lAYNbqShnz3jLHn4OdBmS2L9oXI6pKkm0A1ESkYTOsx1EK8dxwECkTi6AQgOJo79NAmhGg'},
#    '/NxRLab/ModernRobotics/unstar': {'post': '8J4kWF-wCbQiUlOWsqU5X7o4qNUSdDSoMFSmVouFQ37R20lf5uGNvgzOlfOditz14o1VBI_FalX5ho8CVFtGoQ'},
#    '/mithi/robotics-coursework/star': {'post': 'LEkNTsRKYpw5tqRWQrqnDperbO444YoI2nQZwjbbqyatxCQ3dqRoKkG0glTBkbdojR70-UCIBmD88ieiX5nraw'},
#    '/mithi/robotics-coursework/unstar': {'post': 'C3je4i6wfwqmFbdeAi-ImFYIwI46FunCZ-4sQm67RTPi4T2lVS8_KYUR_XjkfKnOxHghrRSUSMrSlrKdTz1nYA'},
#    '/onlytailei/CppRobotics/star': {'post': '36GJ6mbOnOUTRhHmqMtGKPFSzrKnSjhYgDLVQKMB0Rau-RQ2dTCXYS-laujx0RurfIwIpjToeSs_DllFBpzf9w'},
#    '/onlytailei/CppRobotics/unstar': {'post': 'DzpChCsmQIia48LEzI7UGxRaSvBsupc_eSwLXFzk8kpPIQnFGS9a2Bct85oidKAyAEsuB_nfQLBo9h5AOpbMyQ'},
#    '/JdeRobot/RoboticsAcademy/star': {'post': 'VC-NvoPQhG4exVxP_9lEisvORk7KUvUCv_m0fdSj3LjZfv36e3a0nhxhlOrHgUkH2kcx8X9-5DyFfZhduTzNVg'},
#    '/JdeRobot/RoboticsAcademy/unstar': {'post': '7TZaSjDdyWzCK2wN9OXNPxIg6qhMXsmDGjQZ-dwO3C568q_QkeEY03GCtQ3Ld2MUEUCAI0aDg2x2FJc9Lay-cw'},
#    '/pptacher/probabilistic_robotics/star': {'post': 'UuGzL1jnxMtRf7U_JX43UoUxhlSM6cioUnbqwO-DkFL3l0Vx2VlCjVUEs_ITdXvnCYInN3A-qCLpjNFV9woLFw'},
#    '/pptacher/probabilistic_robotics/unstar': {'post': 'sUrj7lJrRThv8EKpPt3hjrWNJYoq1krDxs3Gq7LFhHVeJANij60s0mZq21c_TP_UWZLUSd_Gv8ZnSJc5QPp4Bw'},
#    '/jslee02/awesome-robotics-libraries/star': {'post': 'm0U5b65tyKcEgRjCyGiK3u47ovt3RQ7s_HV0qi6DZKjh2ZDPuxiD6IsLK07sAPNuU6L11yIdHw1_Fc4xhgKHWA'},
#    '/jslee02/awesome-robotics-libraries/unstar': {'post': 'gViEuWsdOpDJ6SPHbMnxex4t4Ta4h1bJfbUOmreKXVuLy8OUwD6Uxm2tW4r4vx0Omfp4Qw-fPwIeb4gzLbvVRw'},
#    '/petercorke/robotics-toolbox-python/star': {'post': '7Ev_pj8E7jOsRUL7gwzznv01-qsQ5xbnOISX-60VhoFCNQ0ujB3BO23tlGb15WMEq-dZUwlUYB2TsRrTf5J28A'},
#    '/petercorke/robotics-toolbox-python/unstar': {'post': 'ljODfQ9VR6zsi47bXJiCakdMww9MJO9DIh5vP9r88cS2VEQvSqaL52iBypty9sHpv7UT96m40BJ9xjpo1aW9dw'},
#    '/Unity-Technologies/Unity-Robotics-Hub/star': {'post': 'Urhd9RdgJLKMvbT_8Kzc8mN2c8OEE_1wV8s09sWzBry4FLf3p81K3GCOc3WqsX8ssVnvEcTexft4Kqi6BIlfyg'},
#    '/Unity-Technologies/Unity-Robotics-Hub/unstar': {'post': 'P1P87U56_HA4RSkywTgFguFh-oUFgkgD0aRR4SwEi36l-V-4cmm711L6lS7XC8YzYThnXyZFn_UBmtxOuMSaDQ'},
#    '/sponsors/batch_deferred_sponsor_buttons': {'post': '8GCQ5K8OcbAdVSkUtvhPHT-7oVtX98zZxjPPVfimAKU0NvzOSsbG_ua3bopqcZZO3fXdvq1eJDhjZU2LeKRdBA'}}},
#  'title': 'Repository search results'}

# %%
repo_name = repos['payload']['results'][0]['hl_name']
repo_name = re.sub(r"<\/?em>", "", repo_name)

# %%
repo_name
# Out:
# 'AtsushiSakai/PythonRobotics'

# %%
# i have to set a condition before the for loop 
if 'payload' in repos and 'results' in repos['payload']:
    # now i can for loop it
    for result in repos['payload']['results']:
        repo_name = result['hl_name']
        repo_name = re.sub(r"<\/?em>", "", repo_name)
        print(repo_name)
# Out:
# AtsushiSakai/PythonRobotics
# kiloreux/awesome-robotics
# NxRLab/ModernRobotics
# mithi/robotics-coursework
# onlytailei/CppRobotics
# JdeRobot/RoboticsAcademy
# pptacher/probabilistic_robotics
# jslee02/awesome-robotics-libraries
# petercorke/robotics-toolbox-python
# Unity-Technologies/Unity-Robotics-Hub

# %% [markdown]
# # acquire function

# %%
import acquire as a
import re
import time
import json

# Define the URL template without the page number
url_template = "https://github.com/search?q=robotics+stars%3A%3E200&type=repositories&p={page}"

# Set the initial page to 1
page = 0
pages = 68
rate_limit_reset = 0  # Initialize to 0 to ensure the first request is made

repositories = []

while page <= pages:
    page += 1

    # Build the URL for the current page
    url = url_template.format(page=page)

    # Check if it's time to sleep to avoid rate limiting
    current_time = time.time()
    if current_time < rate_limit_reset:
        time_to_sleep = rate_limit_reset - current_time
        print(f"Rate limit exceeded. Sleeping for {time_to_sleep} seconds.")
        time.sleep(time_to_sleep)

    # Make the request
    repos = a.github_api_request(url)

    # Check if there are results in the payload
    if 'payload' in repos and 'results' in repos['payload']:
        results = []
        for result in repos['payload']['results']:
            repo_name = result['hl_name']
            repo_name = re.sub(r"<\/?em>", "", repo_name)
            results.append(repo_name)
            print(repo_name)

        # Extend the repositories list only if there are new results
        if results:
            repositories.extend(results)
    else:
        print(f"No results found on page {page}\n\n")

    # Check if there are more pages
    if page % 5 == 0:
        print(f"\n\nacquired pages: {page}")
        time.sleep(60)

# Now you can save the repository names to a JSON file
with open("repo_names.json", 'w') as file:
    json.dump(repositories, file)
# Out:
# AtsushiSakai/PythonRobotics
# kiloreux/awesome-robotics
# NxRLab/ModernRobotics
# mithi/robotics-coursework
# onlytailei/CppRobotics
# JdeRobot/RoboticsAcademy
# pptacher/probabilistic_robotics
# jslee02/awesome-robotics-libraries
# petercorke/robotics-toolbox-python
# Unity-Technologies/Unity-Robotics-Hub
# petercorke/robotics-toolbox-matlab
# AprilRobotics/apriltag
# qqfly/how-to-learn-robotics
# microsoft/PromptCraft-Robotics
# ahundt/awesome-robotics
# rwaldron/johnny-five
# RobotLocomotion/drake
# google-research/robotics_transformer
# kornia/kornia
# qboticslabs/ros_robotics_projects
# vmayoral/ros-robotics-companies
# wuhaoran996/openRobotics
# GT-RIPL/Awesome-LLM-Robotics
# yvonshong/Probabilistic-Robotics
# hubotio/hubot
# Le0nX/ModernRoboticsCpp
# ros/ros_comm
# PetoiCamp/OpenCat
# cyberbotics/webots
# CHH3213/chhRobotics
# araffin/robotics-rl-srl
# ompl/ompl
# foxglove/studio
# hybridgroup/gobot
# mathworks-robotics/awesome-matlab-robotics
# JanuszBedkowski/gpu_computing_in_robotics
# CHH3213/chhRobotics_CPP
# ros-planning/navigation
# AaronMR/Learning_ROS_for_Robotics_Programming_2nd_edition
# rosbook/effective_robotics_programming_with_ros
# Farama-Foundation/Gymnasium-Robotics
# facebookresearch/pyrobot
# giacomo-b/CppRobotics
# mjyc/awesome-robotics-projects
# michiganrobotics/rob501
# google-deepmind/mujoco
# mathiasmantelli/awesome-mobile-robotics
# ros-planning/navigation2
# Unity-Technologies/Robotics-Nav2-SLAM-Example
# zubair-irshad/Awesome-Implicit-NeRF-Robotics
#
#
# acquired pages: 5
# dartsim/dart
# rdiankov/openrave
# ihmcrobotics/ihmc-open-robotics-software
# ros-industrial/universal_robot
# aurora-opensource/streetscape.gl
# ros2/ros2
# Unity-Technologies/Robotics-Object-Pose-Estimation
# owocki/pytrader
# uuvsimulator/uuv_simulator
# msadowski/awesome-weekly-robotics
# NVIDIA-AI-IOT/redtail
# bulletphysics/bullet3
# hybridgroup/cylon
# YashBansod/Robotics-Planning-Dynamics-and-Control
# ANYbotics/kindr
# krishauser/RoboticSystemsBook
# PX4/PX4-SITL_gazebo-classic
# neka-nat/cupoch
# lugh56/control-and-system-book
# karlkurzer/path_planner
# mint-lab/awesome-robotics-datasets
# jrin771/Everything-LLMs-And-Robotics
# google-deepmind/dm_robotics
# real-stanford/diffusion_policy
# cartographer-project/cartographer
# ethz-asl/voxblox
# norlab-ulaval/libpointmatcher
# ros-planning/moveit
# ros-visualization/rviz
# pypose/pypose
# UiPath/ReFrameWork
# leggedrobotics/ros_best_practices
# robotframework/SeleniumLibrary
# Introduction-to-Autonomous-Robots/Introduction-to-Autonomous-Robots
# UMich-CURLY-teaching/UMich-ROB-530-public
# alexbaucom17/DominoRobot
# gazebosim/gz-sim
# opendr-eu/opendr
# openai/robogym
# NVIDIA-Omniverse/Orbit
# nasa/astrobee
# hbrobotics/ros_arduino_bridge
# zeke/semantic-pull-requests
# wh200720041/ssl_slam
# ros-planning/moveit2
# hybridgroup/artoo
# symforce-org/symforce
# ryuichiueda/LNPR_BOOK_CODES
# justmarkham/scikit-learn-tips
# uzh-rpg/rpg_quadrotor_control
#
#
# acquired pages: 10
# poppy-project/poppy-humanoid
# MRPT/mrpt
# askrella/whatsapp-chatgpt
# rtv/Stage
# automagica/automagica
# ftctechnh/ftc_app
# atenpas/gpd
# ANYbotics/grid_map
# Farama-Foundation/Metaworld
# pandolia/qqbot
# xipengwang/AprilSAM
# engnadeau/pybotics
# ANYbotics/elevation_mapping
# PetoiCamp/OpenCat-Old
# NVIDIA-AI-IOT/jetbot
# RoboStack/ros-noetic
# the-blue-alliance/the-blue-alliance
# ethz-adrl/control-toolbox
# qboticslabs/mastering_ros
# robotframework/RIDE
# google-research/tensor2robot
# MAPIRlab/rf2o_laser_odometry
# Opentrons/opentrons
# ppodgorsek/docker-robot-framework
# michiganrobotics/rob101
# mikeferguson/ros2_cookbook
# AngelLM/Thor
# fredoverflow/karel
# SintefManufacturing/python-urx
# lgsvl/simulator
# robotframework/QuickStartGuide
# ilpincy/argos3
# hungpham2511/toppra
# isl-org/OpenBot
# nokia/RED
# mjbots/moteus
# google/brax
# ros-controls/ros_controllers
# utiasSTARS/pykitti
# openrr/openrr
# dougsm/ggcnn
# ClemensElflein/OpenMower
# ros2/rviz
# aurora-opensource/xviz
# SJTU-ViSYS/M2DGR
# google-deepmind/tapnet
# Hypfer/Valetudo
# simbody/simbody
# robotology/yarp
# robotopia-x/robotopia
#
#
# acquired pages: 15
# charlesq34/frustum-pointnets
# AutoRally/autorally
# nmccrea/sobot-rimulator
# splintered-reality/py_trees
# G-Levine/OpenTorque-Actuator
# AtsushiSakai/MATLABRobotics
# 4ndreas/BetaBots-Robot-Arm-Project
# MyRobotLab/myrobotlab
# leggedrobotics/legged_gym
# ros-industrial/ur_modern_driver
# mengyuest/iros2018-slam-papers
# wpilibsuite/GradleRIO
# FidoProject/Fido
# BCN3D/BCN3D-Moveo
# spectresystems/jarvis
# jcrocholl/kossel
# HKUST-Aerial-Robotics/open_quadtree_mapping
# mlaiacker/rosbag2video
# Chris-Annin/AR2
# nasa-jpl/open-source-rover
# mangdangroboticsclub/QuadrupedRobot
# openTCS/opentcs
# mikeferguson/robot_calibration
# MiRoboticsLab/cyberdog_ros2
# DexterInd/GoPiGo
# dusty-nv/jetson-reinforcement
# hugs/tapsterbot
# MarketSquare/robotframework-requests
# at-wat/neonavigation
# andyzeng/arc-robot-vision
# MegviiRobot/CamLaserCalibraTool
# stepjam/PyRep
# jcrocholl/rostock
# BYU-PCCL/holodeck
# leggedrobotics/ocs2
# vmayoral/robot_hacking_manual
# wh200720041/ssl_slam2
# leggedrobotics/raisimLib
# frankaemika/franka_ros
# ARISE-Initiative/robosuite
# RoboMaster/RoboRTS
# pantor/ros-control-center
# UniversalRobots/Universal_Robots_ROS_Driver
# hrnr/m-explore
# HKUST-Aerial-Robotics/DenseSurfelMapping
# linorobot/linorobot
# openai/roboschool
# amslabtech/dwa_planner
# jason718/awesome-self-supervised-learning
# fkromer/awesome-ros2
#
#
# acquired pages: 20
# wh200720041/floam
# undera/pylgbst
# PaoPaoRobot/ICRA2020-paper-list
# PRBonn/bonnet
# Kinovarobotics/kinova-ros
# ethz-asl/ethzasl_icp_mapping
# HKUST-Aerial-Robotics/FIESTA
# iosre/WeChatRobotForExample
# unitreerobotics/unitree_legged_sdk
# ros-controls/ros2_controllers
# facebookresearch/votenet
# jizhang-cmu/ground_based_autonomy_basic
# paperswithcode/ai-deadlines
# abr/abr_control
# ros-planning/navigation_experimental
# JackieTseng/conference_call_for_paper
# ros2-rust/ros2_rust
# robotframework/WebDemo
# dojo-sim/Dojo.jl
# GeorgeDu/vision-based-robotic-grasping
# botgram/shell-bot
# haosulab/ManiSkill2
# Nate711/StanfordDoggoProject
# cbfinn/gps
# mkorpela/pabot
# gramaziokohler/roslibpy
# roboticslibrary/rl
# facebookresearch/habitat-sim
# andrewliao11/Deep-Reinforcement-Learning-Survey
# wechaty/wechaty
# apollographql/apollo-kotlin
# yujinrobot/yujin_ocs
# gradslam/gradslam
# CoretechR/ZeroBug
# unmannedlab/RELLIS-3D
# telegram-sms/telegram-sms
# erwincoumans/tiny-differentiable-simulator
# taichi-dev/difftaichi
# songtianyi/wechat-go
# gogojjh/M-LOAM
# mozilla/TTS
# url-kaist/dynaVINS
# MIT-SPARK/TEASER-plusplus
# BehaviorTree/BehaviorTree.CPP
# curieuxjy/Awesome_Quadrupedal_Robots
# aravindr93/mjrl
# borglab/gtsam
# ontodev/robot
# ori-drs/pronto
# steeply/gbot-trader
#
#
# acquired pages: 25
# linorobot/linorobot2
# robocorp/rpaframework
# skumra/robotic-grasping
# cajt/list_of_robot_electronics
# anki/vector-python-sdk
# ros-simulation/gazebo_ros_demos
# MarketSquare/robotframework-browser
# Healthcare-Robotics/assistive-gym
# mithi/hexapod-robot-simulator
# stereolabs/zed-sdk
# OttoDIY/OttoNinja
# scala-steward-org/scala-steward
# MIT-SPARK/Kimera
# MrinmoiHossain/Online-Courses-Learning
# Phylliade/ikpy
# osrf/rosbook
# tesseract-robotics/tesseract
# dydxprotocol/liquidator
# glumb/robot-gui
# sychaichangkun/ROS-Academy-for-Beginners
# PaoPaoRobot/IROS2020-paper-list
# StockSharp/StockSharp
# jr-robotics/robo-gym
# robotattackorg/robot-detect
# arviedelgado/roro
# webfansplz/volute
# rerun-io/rerun
# vikashplus/robohive
# tianheyu927/mil
# iris-ua/iris_lama
# carlosmccosta/dynamic_robot_localization
# NeBula-Autonomy/LAMP
# evildmp/BrachioGraph
# PaoPaoRobot/IROS2019-paper-list
# m4mallu/clonebot
# ros-controls/ros2_control_demos
# serialport/node-serialport
# andrewkirillov/AForge.NET
# atb033/multi_agent_path_planning
# nestjs/terminus
# andybarry/flight
# snape/RVO2
# graydon/bors
# erwincoumans/motion_imitation
# robotframework/HowToWriteGoodTestCases
# heuristicus/spot_ros
# glumb/kinematics
# adityadua24/robopy
# danijar/dreamer
# ZiwenZhuang/parkour
#
#
# acquired pages: 30
# PRBonn/SHINE_mapping
# udacity/robot_pose_ekf
# RoboStack/jupyter-ros
# nicrusso7/rex-gym
# jimmyyhwu/tidybot
# lazyparser/weloveinterns
# meganetaaan/stack-chan
# SteveMacenski/jetson_nano_detection_and_tracking
# robotlearn/pyrobolearn
# UniversalRobots/Universal_Robots_ROS2_Driver
# at-wat/mcl_3dl
# leggedrobotics/free_gait
# htnanako/movie-robot-public
# robotology/gym-ignition
# dongjing3309/minisam
# RuslanAgishev/motion_planning
# gtrll/gpmp2
# saucepleez/taskt
# eProsima/Fast-DDS
# mikeroyal/Photogrammetry-Guide
# mithi/hexapod
# buzz-lang/Buzz
# leggedrobotics/delora
# marcelrv/XiaomiRobotVacuumProtocol
# Geonhee-LEE/mpc_ros
# foxglove/mcap
# xdspacelab/openvslam
# StanfordVL/iGibson
# greenkeeperio/greenkeeper
# sopel-irc/sopel
# vita-epfl/CrowdNav
# cliport/cliport
# snape/RVO2-CS
# oceanlvr/ChatGPT-ProBot
# SkyentificGit/SmallRobotArm
# wsnewman/learning_ros
# FlorianWilk/SpotMicroAI
# MorvanZhou/train-robot-arm-from-scratch
# nebrius/raspi-io
# PCrnjak/Faze4-Robotic-arm
# Lakr233/BBackupp
# leggedrobotics/xpp
# ARISE-Initiative/robomimic
# ethz-adrl/towr
# JsonChao/ML-Roadmap
# zhuhu00/Awesome_Dynamic_SLAM
# rbdl/rbdl
# PRBonn/kiss-icp
# PRBonn/bonnetal
# BR-IDL/PaddleViT
#
#
# acquired pages: 35
# ternaus/robot-surgery-segmentation
# moonglow/pcan_cantact
# url-kaist/UV-SLAM
# ros-planning/robot_pose_ekf
# jedeschaud/ct_icp
# Lionelsy/Conference-Accepted-Paper-List
# pantor/frankx
# fkromer/awesome-robotframework
# avisingh599/reward-learning-rl
# visose/Robots
# wangcongrobot/awesome-isaac-gym
# cogsys-tuebingen/gerona
# protontypes/awesome-robotic-tooling
# sphero-inc/sphero.js
# clvrai/furniture
# rst-tu-dortmund/teb_local_planner
# mattes/go-asciibot
# A9T9/RPA
# rpng/open_vins
# Improbable-AI/walk-these-ways
# OpnTec/fashionmaker
# strasdat/Sophus
# Ardumower/ardumower
# pantor/ruckig
# airalab/robonomics
# awesome-photogrammetry/awesome-photogrammetry
# node-webot/weixin-robot
# moble/quaternion
# LinuxCNC/linuxcnc
# mit-acl/cadrl_ros
# Dice-Developer-Team/Dice
# AndrejOrsula/drl_grasping
# whoenig/libMultiRobotPlanning
# graspnet/graspnet-baseline
# mahowik/BalancingWii
# methylDragon/ros-sensor-fusion-tutorial
# calcmogul/controls-engineering-in-frc
# mayataka/robotoc
# wpietri/sucks
# zuoym15/craves.ai
# EA31337/EA31337
# qgallouedec/panda-gym
# hku-mars/ikd-Tree
# mjansen4857/pathplanner
# VIS4ROB-lab/ccm_slam
# yankailab/OpenKAI
# visionworkbench/visionworkbench
# areed1192/python-trading-robot
# introlab/rtabmap
# ShuoYangRobotics/Cerberus
#
#
# acquired pages: 40
# bytedance/ibot
# exAspArk/awesome-chatops
# chonyy/AI-basketball-analysis
# i2Nav-WHU/Wheel-INS
# andyzeng/visual-pushing-grasping
# lucidrains/robotic-transformer-pytorch
# dheera/rosboard
# ScRiPt1337/Teardroid-phprat
# zz570557024/vue-mpvue-ChatRobot
# appliedAI-Initiative/orb_slam_2_ros
# evanw/rapt
# zexiplus/WALL.E
# kyprizel/testcookie-nginx-module
# pirxthepilot/wtfis
# facebookresearch/iSDF
# aholstenson/miio
# engcang/SLAM-application
# lardemua/atom
# DoongLi/awesome-Implicit-NeRF-SLAM
# tynguyen/unsupervisedDeepHomographyRAL2018
# qiayuanliao/legged_control
# monperrus/crawler-user-agents
# pliang279/awesome-multimodal-ml
# miccol/ROS-Behavior-Tree
# shekit/peeqo-robot
# osrf/gazebo_models
# BerkeleyAutomation/gqcnn
# Derek-TH-Wang/quadruped_ctrl
# caochao39/aerial_navigation_development_environment
# devanhurst/ktane_voice
# jazzband/django-robots
# projectchrono/chrono
# LiJiangnanBit/path_optimizer
# ClemensElflein/xESC
# Tasshack/dreame-vacuum
# fkie/multimaster_fkie
# APRIL-ZJU/CL-CBS
# RobotLocomotion/pytorch-dense-correspondence
# lich0821/WeChatRobot
# nategri/nematoduino
# Deeplocal/mocktailsmixer
# personalrobotics/aikido
# facebookresearch/habitat-lab
# alajmo/mani
# basnijholt/home-assistant-config
# opencog/opencog
# snape/RVO2-3D
# semitable/robotic-warehouse
# dora-rs/dora
# iuiaoin/wechat-gptbot
#
#
# acquired pages: 45
# chengxuxin/extreme-parkour
# cyandterry/Like-My-GF
# MISTLab/DOOR-SLAM
# peract/peract
# sergionr2/RacingRobot
# Salman-H/pick-place-robot
# PaulDanielML/MuJoCo_RL_UR5
# probcomp/Gen.jl
# mjl/particle_filter_demo
# eclipse/repairnator
# ori-mrg/robotcar-dataset-sdk
# zauberzeug/nicegui
# Jaeyoung-Lim/mavros_controllers
# dotchen/LearningByCheating
# introlab/odas
# danijar/dreamerv2
# chvmp/champ
# pglira/simpleICP
# PeterFWS/Structure-PLP-SLAM
# mackorone/mms
# aniskoubaa/rosgpt
# garrows/browser-serialport
# lucasfcosta/dotfiles
# MichaelGrupp/evo
# kindredresearch/SenseAct
# Developer-Y/cs-video-courses
# vimalabs/VIMA
# AnyLoc/AnyLoc
# rishabh1b/RealTimePathPlanning
# cra-ros-pkg/robot_localization
# OpenOCL/OpenOCL
# folke/devmoji
# alajmo/sake
# lihuang3/ur5_ROS-Gazebo
# Acmece/rl-collision-avoidance
# DLR-RM/stable-baselines3
# MIT-SPARK/Kimera-VIO
# nonebot/nonebot
# yuce/pyswip
# w111liang222/lidar-slam-detection
# yangyanli/PointCNN
# erwincoumans/pybullet_robots
# devendrachaplot/Neural-SLAM
# spencer-project/spencer_people_tracking
# facebookresearch/differentiable-robot-model
# shannon112/awesome-ros-mobile-robot
# NVIDIA-ISAAC-ROS/isaac_ros_nvblox
# benct/lovelace-xiaomi-vacuum-card
# chriskiehl/pyrobot
# 546669204/RebateBot
#
#
# acquired pages: 50
# dfki-ric/phobos
# quasilyte/roboden-game
# wkentaro/morefusion
# Tai-Wang/Depth-from-Motion
# beardicus/awesome-plotters
# dji-sdk/Onboard-SDK
# pal-robotics/aruco_ros
# RoboJackets/rrt
# WPIRoboticsProjects/GRIP
# TianhongDai/hindsight-experience-replay
# nebrius/raspi
# metakirby5/yorha
# p-org/P
# izhengfan/se2lam
# 26hzhang/DL-NLP-Readings
# go-joe/joe
# ArghyaChatterjee/gps-waypoint-based-autonomous-navigation-in-ros
# Doragd/Chinese-Chatbot-PyTorch-Implementation
# VitoVan/cl-dino
# Unity-Technologies/ROS-TCP-Connector
# AcutronicRobotics/gym-gazebo2
# RobotWebTools/rclnodejs
# nvidia-isaac/nvblox
# star2dust/paper-simulation
# ScienJus/smartqq
# Simple-Robotics/proxsuite
# StanfordVL/GibsonEnv
# tinymovr/Tinymovr
# ArduPilot/ardupilot
# nickpettican/InstaBot
# lavabit/robox
# MISTLab/Swarm-SLAM
# ScienJus/qqbot
# simple-robot/simpler-robot
# RoboDK/RoboDK-API
# huihut/Facemoji
# rdbox-intec/rdbox
# stil/curl-easy
# D4Vinci/elpscrk
# schodet/nxt-python
# HITSZ-NRSL/Dynamic-VINS
# CopterExpress/clover
# reiniscimurs/DRL-robot-navigation
# facebookresearch/theseus
# bmartin5692/bumper
# aau-cns/mars_lib
# ezelikman/parsel
# ZJU-FAST-Lab/EGO-Planner-v2
# koalazak/dorita980
# keenon/nimblephysics
#
#
# acquired pages: 55
# schroederdewitt/multiagent_mujoco
# xiihoo/Books_Robot_SLAM_Navigation
# Hypfer/lovelace-valetudo-map-card
# jesseweisberg/moveo_ros
# changh95/visual-slam-roadmap
# robosoft-ai/SMACC
# NVIDIA-ISAAC-ROS/isaac_ros_visual_slam
# hybridgroup/gort
# yybawang/laravel-ebank
# google-research/ravens
# pliang279/MultiBench
# loco-3d/crocoddyl
# MetaSLAM/AutoMerge_Docker
# m2n037/awesome-mecheng
# openrr/urdf-viz
# aws-robotics/aws-robomaker-small-warehouse-world
# microsoft/AutonomousDrivingCookbook
# poppy-project/pypot
# Emotional-Text-to-Speech/dl-for-emo-tts
# artivis/manif
# bolderflight/sbus
# ros-controls/ros2_control
# dusty-nv/jetson-inference
# NaiboWang/EasySpider
# DJTobias/Cherry-Autonomous-Racecar
# vectr-ucla/direct_lidar_odometry
# ugurkanates/awesome-real-world-rl
# xinshuoweng/AB3DMOT
# chapulina/dolly
# bolderflight/invensense-imu
# locusrobotics/fuse
# maelstrom-cms/odin
# utiasDSL/gym-pybullet-drones
# NeoGeographyToolkit/StereoPipeline
# cagbal/ros_people_object_detection_tensorflow
# facebookresearch/ContactPose
# cyberbotics/webots_ros2
# gkjohnson/urdf-loaders
# leggedrobotics/open3d_slam
# ethz-adrl/ifopt
# Gaochao-hit/LIO-SAM_based_relocalization
# hasauino/rrt_exploration
# devendrachaplot/Object-Goal-Navigation
# Tobias-Fischer/rt_gene
# MegaMek/megamek
# gazebosim/gazebo-classic
# lianghongzhuo/PointNetGPD
# utiasDSL/safe-control-gym
# MIT-SPARK/Kimera-Semantics
# microsoft/AirSim-NeurIPS2019-Drone-Racing
#
#
# acquired pages: 60
# Stable-Baselines-Team/stable-baselines3-contrib
# go-skynet/LocalAI
# DLR-RM/rl-baselines3-zoo
# caelan/pddlstream
# robocorp/rcc
# awesome-vacuum/awesome-vacuum
# sichkar-valentyn/Reinforcement_Learning_in_Python
# caelan/pybullet-planning
# vibertthio/awesome-machine-learning-art
# Vincentqyw/cv-arxiv-daily
# rgommezz/react-native-chatgpt
# PRBonn/depth_clustering
# jhu-lcsr/handeye_calib_camodocal
# nickcharron/waypoint_nav
# Sollimann/CleanIt
# Firmament-Autopilot/FMT-Firmware
# stack-of-tasks/pinocchio
# aixed/WeChat-Hook
# vectr-ucla/direct_lidar_inertial_odometry
# OpenCyphal-Garage/libcyphal
# UMich-BipedLab/LiDARTag
# adham-elarabawy/open-quadruped
# wil3/gymfc
# sphero-inc/Sphero-iOS-SDK
# wzpan/wukong-robot
# Unity-Technologies/articulations-robot-demo
# treflehq/trefle-api
# stackgpu/Simple-GPU
# yuanmingqi/rl-exploration-baselines
# sail-sg/envpool
# graniet/fsociety-ransomware-MrRobot
# eclipse-zenoh/zenoh
# omegaiota/DiffCloth
# ethz-asl/polygon_coverage_planning
# JuliaRobotics/RigidBodyDynamics.jl
# wenbowen123/catgrasp
# mathworks/MATLAB-Simulink-Challenge-Project-Hub
# RLE-Foundation/rllte
# OpenRL-Lab/openrl
# artivis/kalmanif
# tnikolla/robot-grasp-detection
# google/mobly
# usdot-fhwa-stol/carma-platform
# bark-simulator/bark
# ai-winter/ros_motion_planning
# vipjeffreylee/QQrobot
# OpenCyphal/libcanard
# BrianPugh/belay
# arouel/uadetector
# zubair-irshad/CenterSnap
#
#
# acquired pages: 65
# wenbowen123/BundleTrack
# zhayujie/chatgpt-on-wechat
# wenbowen123/iros20-6d-pose-tracking
# WhiteWatson/wx-bot-client
# UMich-BipedLab/extrinsic_lidar_camera_calibration
# BAILOOL/ANMS-Codes
# michaelkubina/SpotMicroESP32
# navneet-nmk/pytorch-rl
# Devs-Dungeon/Resources
# ros-mobile-robots/diffbot
# Toni-SM/skrl
# alphaville/optimization-engine
# osvt/TeamHelper
# napframework/nap
# vs4vijay/SwissArmyPi
# Skythinker616/foc-wheel-legged-robot
# DmitryRyumin/ICCV-2023-Papers
# Sollimann/bonsai
# sachink2010/AutomatedStockTrading-DeepQ-Learning
# zjunlp/EasyInstruct
# RajashekarRaju/compose-actors
# MMehrez/MPC-and-MHE-implementation-in-MATLAB-using-Casadi
# CatchZeng/dingtalk
# 1c7/Translate-Subtitle-File
# landy22granatt/Kumpulan-Script-Termux
# cirosantilli/china-dictatorship
# gege-circle/home

# %%
repositories[:677]
# Out:
# ['AtsushiSakai/PythonRobotics',
#  'kiloreux/awesome-robotics',
#  'NxRLab/ModernRobotics',
#  'mithi/robotics-coursework',
#  'onlytailei/CppRobotics',
#  'JdeRobot/RoboticsAcademy',
#  'pptacher/probabilistic_robotics',
#  'jslee02/awesome-robotics-libraries',
#  'petercorke/robotics-toolbox-python',
#  'Unity-Technologies/Unity-Robotics-Hub',
#  'petercorke/robotics-toolbox-matlab',
#  'AprilRobotics/apriltag',
#  'qqfly/how-to-learn-robotics',
#  'microsoft/PromptCraft-Robotics',
#  'ahundt/awesome-robotics',
#  'rwaldron/johnny-five',
#  'RobotLocomotion/drake',
#  'google-research/robotics_transformer',
#  'kornia/kornia',
#  'qboticslabs/ros_robotics_projects',
#  'vmayoral/ros-robotics-companies',
#  'wuhaoran996/openRobotics',
#  'GT-RIPL/Awesome-LLM-Robotics',
#  'yvonshong/Probabilistic-Robotics',
#  'hubotio/hubot',
#  'Le0nX/ModernRoboticsCpp',
#  'ros/ros_comm',
#  'PetoiCamp/OpenCat',
#  'cyberbotics/webots',
#  'CHH3213/chhRobotics',
#  'araffin/robotics-rl-srl',
#  'ompl/ompl',
#  'foxglove/studio',
#  'hybridgroup/gobot',
#  'mathworks-robotics/awesome-matlab-robotics',
#  'JanuszBedkowski/gpu_computing_in_robotics',
#  'CHH3213/chhRobotics_CPP',
#  'ros-planning/navigation',
#  'AaronMR/Learning_ROS_for_Robotics_Programming_2nd_edition',
#  'rosbook/effective_robotics_programming_with_ros',
#  'Farama-Foundation/Gymnasium-Robotics',
#  'facebookresearch/pyrobot',
#  'giacomo-b/CppRobotics',
#  'mjyc/awesome-robotics-projects',
#  'michiganrobotics/rob501',
#  'google-deepmind/mujoco',
#  'mathiasmantelli/awesome-mobile-robotics',
#  'ros-planning/navigation2',
#  'Unity-Technologies/Robotics-Nav2-SLAM-Example',
#  'zubair-irshad/Awesome-Implicit-NeRF-Robotics',
#  'dartsim/dart',
#  'rdiankov/openrave',
#  'ihmcrobotics/ihmc-open-robotics-software',
#  'ros-industrial/universal_robot',
#  'aurora-opensource/streetscape.gl',
#  'ros2/ros2',
#  'Unity-Technologies/Robotics-Object-Pose-Estimation',
#  'owocki/pytrader',
#  'uuvsimulator/uuv_simulator',
#  'msadowski/awesome-weekly-robotics',
#  'NVIDIA-AI-IOT/redtail',
#  'bulletphysics/bullet3',
#  'hybridgroup/cylon',
#  'YashBansod/Robotics-Planning-Dynamics-and-Control',
#  'ANYbotics/kindr',
#  'krishauser/RoboticSystemsBook',
#  'PX4/PX4-SITL_gazebo-classic',
#  'neka-nat/cupoch',
#  'lugh56/control-and-system-book',
#  'karlkurzer/path_planner',
#  'mint-lab/awesome-robotics-datasets',
#  'jrin771/Everything-LLMs-And-Robotics',
#  'google-deepmind/dm_robotics',
#  'real-stanford/diffusion_policy',
#  'cartographer-project/cartographer',
#  'ethz-asl/voxblox',
#  'norlab-ulaval/libpointmatcher',
#  'ros-planning/moveit',
#  'ros-visualization/rviz',
#  'pypose/pypose',
#  'UiPath/ReFrameWork',
#  'leggedrobotics/ros_best_practices',
#  'robotframework/SeleniumLibrary',
#  'Introduction-to-Autonomous-Robots/Introduction-to-Autonomous-Robots',
#  'UMich-CURLY-teaching/UMich-ROB-530-public',
#  'alexbaucom17/DominoRobot',
#  'gazebosim/gz-sim',
#  'opendr-eu/opendr',
#  'openai/robogym',
#  'NVIDIA-Omniverse/Orbit',
#  'nasa/astrobee',
#  'hbrobotics/ros_arduino_bridge',
#  'zeke/semantic-pull-requests',
#  'wh200720041/ssl_slam',
#  'ros-planning/moveit2',
#  'hybridgroup/artoo',
#  'symforce-org/symforce',
#  'ryuichiueda/LNPR_BOOK_CODES',
#  'justmarkham/scikit-learn-tips',
#  'uzh-rpg/rpg_quadrotor_control',
#  'poppy-project/poppy-humanoid',
#  'MRPT/mrpt',
#  'askrella/whatsapp-chatgpt',
#  'rtv/Stage',
#  'automagica/automagica',
#  'ftctechnh/ftc_app',
#  'atenpas/gpd',
#  'ANYbotics/grid_map',
#  'Farama-Foundation/Metaworld',
#  'pandolia/qqbot',
#  'xipengwang/AprilSAM',
#  'engnadeau/pybotics',
#  'ANYbotics/elevation_mapping',
#  'PetoiCamp/OpenCat-Old',
#  'NVIDIA-AI-IOT/jetbot',
#  'RoboStack/ros-noetic',
#  'the-blue-alliance/the-blue-alliance',
#  'ethz-adrl/control-toolbox',
#  'qboticslabs/mastering_ros',
#  'robotframework/RIDE',
#  'google-research/tensor2robot',
#  'MAPIRlab/rf2o_laser_odometry',
#  'Opentrons/opentrons',
#  'ppodgorsek/docker-robot-framework',
#  'michiganrobotics/rob101',
#  'mikeferguson/ros2_cookbook',
#  'AngelLM/Thor',
#  'fredoverflow/karel',
#  'SintefManufacturing/python-urx',
#  'lgsvl/simulator',
#  'robotframework/QuickStartGuide',
#  'ilpincy/argos3',
#  'hungpham2511/toppra',
#  'isl-org/OpenBot',
#  'nokia/RED',
#  'mjbots/moteus',
#  'google/brax',
#  'ros-controls/ros_controllers',
#  'utiasSTARS/pykitti',
#  'openrr/openrr',
#  'dougsm/ggcnn',
#  'ClemensElflein/OpenMower',
#  'ros2/rviz',
#  'aurora-opensource/xviz',
#  'SJTU-ViSYS/M2DGR',
#  'google-deepmind/tapnet',
#  'Hypfer/Valetudo',
#  'simbody/simbody',
#  'robotology/yarp',
#  'robotopia-x/robotopia',
#  'charlesq34/frustum-pointnets',
#  'AutoRally/autorally',
#  'nmccrea/sobot-rimulator',
#  'splintered-reality/py_trees',
#  'G-Levine/OpenTorque-Actuator',
#  'AtsushiSakai/MATLABRobotics',
#  '4ndreas/BetaBots-Robot-Arm-Project',
#  'MyRobotLab/myrobotlab',
#  'leggedrobotics/legged_gym',
#  'ros-industrial/ur_modern_driver',
#  'mengyuest/iros2018-slam-papers',
#  'wpilibsuite/GradleRIO',
#  'FidoProject/Fido',
#  'BCN3D/BCN3D-Moveo',
#  'spectresystems/jarvis',
#  'jcrocholl/kossel',
#  'HKUST-Aerial-Robotics/open_quadtree_mapping',
#  'mlaiacker/rosbag2video',
#  'Chris-Annin/AR2',
#  'nasa-jpl/open-source-rover',
#  'mangdangroboticsclub/QuadrupedRobot',
#  'openTCS/opentcs',
#  'mikeferguson/robot_calibration',
#  'MiRoboticsLab/cyberdog_ros2',
#  'DexterInd/GoPiGo',
#  'dusty-nv/jetson-reinforcement',
#  'hugs/tapsterbot',
#  'MarketSquare/robotframework-requests',
#  'at-wat/neonavigation',
#  'andyzeng/arc-robot-vision',
#  'MegviiRobot/CamLaserCalibraTool',
#  'stepjam/PyRep',
#  'jcrocholl/rostock',
#  'BYU-PCCL/holodeck',
#  'leggedrobotics/ocs2',
#  'vmayoral/robot_hacking_manual',
#  'wh200720041/ssl_slam2',
#  'leggedrobotics/raisimLib',
#  'frankaemika/franka_ros',
#  'ARISE-Initiative/robosuite',
#  'RoboMaster/RoboRTS',
#  'pantor/ros-control-center',
#  'UniversalRobots/Universal_Robots_ROS_Driver',
#  'hrnr/m-explore',
#  'HKUST-Aerial-Robotics/DenseSurfelMapping',
#  'linorobot/linorobot',
#  'openai/roboschool',
#  'amslabtech/dwa_planner',
#  'jason718/awesome-self-supervised-learning',
#  'fkromer/awesome-ros2',
#  'wh200720041/floam',
#  'undera/pylgbst',
#  'PaoPaoRobot/ICRA2020-paper-list',
#  'PRBonn/bonnet',
#  'Kinovarobotics/kinova-ros',
#  'ethz-asl/ethzasl_icp_mapping',
#  'HKUST-Aerial-Robotics/FIESTA',
#  'iosre/WeChatRobotForExample',
#  'unitreerobotics/unitree_legged_sdk',
#  'ros-controls/ros2_controllers',
#  'facebookresearch/votenet',
#  'jizhang-cmu/ground_based_autonomy_basic',
#  'paperswithcode/ai-deadlines',
#  'abr/abr_control',
#  'ros-planning/navigation_experimental',
#  'JackieTseng/conference_call_for_paper',
#  'ros2-rust/ros2_rust',
#  'robotframework/WebDemo',
#  'dojo-sim/Dojo.jl',
#  'GeorgeDu/vision-based-robotic-grasping',
#  'botgram/shell-bot',
#  'haosulab/ManiSkill2',
#  'Nate711/StanfordDoggoProject',
#  'cbfinn/gps',
#  'mkorpela/pabot',
#  'gramaziokohler/roslibpy',
#  'roboticslibrary/rl',
#  'facebookresearch/habitat-sim',
#  'andrewliao11/Deep-Reinforcement-Learning-Survey',
#  'wechaty/wechaty',
#  'apollographql/apollo-kotlin',
#  'yujinrobot/yujin_ocs',
#  'gradslam/gradslam',
#  'CoretechR/ZeroBug',
#  'unmannedlab/RELLIS-3D',
#  'telegram-sms/telegram-sms',
#  'erwincoumans/tiny-differentiable-simulator',
#  'taichi-dev/difftaichi',
#  'songtianyi/wechat-go',
#  'gogojjh/M-LOAM',
#  'mozilla/TTS',
#  'url-kaist/dynaVINS',
#  'MIT-SPARK/TEASER-plusplus',
#  'BehaviorTree/BehaviorTree.CPP',
#  'curieuxjy/Awesome_Quadrupedal_Robots',
#  'aravindr93/mjrl',
#  'borglab/gtsam',
#  'ontodev/robot',
#  'ori-drs/pronto',
#  'steeply/gbot-trader',
#  'linorobot/linorobot2',
#  'robocorp/rpaframework',
#  'skumra/robotic-grasping',
#  'cajt/list_of_robot_electronics',
#  'anki/vector-python-sdk',
#  'ros-simulation/gazebo_ros_demos',
#  'MarketSquare/robotframework-browser',
#  'Healthcare-Robotics/assistive-gym',
#  'mithi/hexapod-robot-simulator',
#  'stereolabs/zed-sdk',
#  'OttoDIY/OttoNinja',
#  'scala-steward-org/scala-steward',
#  'MIT-SPARK/Kimera',
#  'MrinmoiHossain/Online-Courses-Learning',
#  'Phylliade/ikpy',
#  'osrf/rosbook',
#  'tesseract-robotics/tesseract',
#  'dydxprotocol/liquidator',
#  'glumb/robot-gui',
#  'sychaichangkun/ROS-Academy-for-Beginners',
#  'PaoPaoRobot/IROS2020-paper-list',
#  'StockSharp/StockSharp',
#  'jr-robotics/robo-gym',
#  'robotattackorg/robot-detect',
#  'arviedelgado/roro',
#  'webfansplz/volute',
#  'rerun-io/rerun',
#  'vikashplus/robohive',
#  'tianheyu927/mil',
#  'iris-ua/iris_lama',
#  'carlosmccosta/dynamic_robot_localization',
#  'NeBula-Autonomy/LAMP',
#  'evildmp/BrachioGraph',
#  'PaoPaoRobot/IROS2019-paper-list',
#  'm4mallu/clonebot',
#  'ros-controls/ros2_control_demos',
#  'serialport/node-serialport',
#  'andrewkirillov/AForge.NET',
#  'atb033/multi_agent_path_planning',
#  'nestjs/terminus',
#  'andybarry/flight',
#  'snape/RVO2',
#  'graydon/bors',
#  'erwincoumans/motion_imitation',
#  'robotframework/HowToWriteGoodTestCases',
#  'heuristicus/spot_ros',
#  'glumb/kinematics',
#  'adityadua24/robopy',
#  'danijar/dreamer',
#  'ZiwenZhuang/parkour',
#  'PRBonn/SHINE_mapping',
#  'udacity/robot_pose_ekf',
#  'RoboStack/jupyter-ros',
#  'nicrusso7/rex-gym',
#  'jimmyyhwu/tidybot',
#  'lazyparser/weloveinterns',
#  'meganetaaan/stack-chan',
#  'SteveMacenski/jetson_nano_detection_and_tracking',
#  'robotlearn/pyrobolearn',
#  'UniversalRobots/Universal_Robots_ROS2_Driver',
#  'at-wat/mcl_3dl',
#  'leggedrobotics/free_gait',
#  'htnanako/movie-robot-public',
#  'robotology/gym-ignition',
#  'dongjing3309/minisam',
#  'RuslanAgishev/motion_planning',
#  'gtrll/gpmp2',
#  'saucepleez/taskt',
#  'eProsima/Fast-DDS',
#  'mikeroyal/Photogrammetry-Guide',
#  'mithi/hexapod',
#  'buzz-lang/Buzz',
#  'leggedrobotics/delora',
#  'marcelrv/XiaomiRobotVacuumProtocol',
#  'Geonhee-LEE/mpc_ros',
#  'foxglove/mcap',
#  'xdspacelab/openvslam',
#  'StanfordVL/iGibson',
#  'greenkeeperio/greenkeeper',
#  'sopel-irc/sopel',
#  'vita-epfl/CrowdNav',
#  'cliport/cliport',
#  'snape/RVO2-CS',
#  'oceanlvr/ChatGPT-ProBot',
#  'SkyentificGit/SmallRobotArm',
#  'wsnewman/learning_ros',
#  'FlorianWilk/SpotMicroAI',
#  'MorvanZhou/train-robot-arm-from-scratch',
#  'nebrius/raspi-io',
#  'PCrnjak/Faze4-Robotic-arm',
#  'Lakr233/BBackupp',
#  'leggedrobotics/xpp',
#  'ARISE-Initiative/robomimic',
#  'ethz-adrl/towr',
#  'JsonChao/ML-Roadmap',
#  'zhuhu00/Awesome_Dynamic_SLAM',
#  'rbdl/rbdl',
#  'PRBonn/kiss-icp',
#  'PRBonn/bonnetal',
#  'BR-IDL/PaddleViT',
#  'ternaus/robot-surgery-segmentation',
#  'moonglow/pcan_cantact',
#  'url-kaist/UV-SLAM',
#  'ros-planning/robot_pose_ekf',
#  'jedeschaud/ct_icp',
#  'Lionelsy/Conference-Accepted-Paper-List',
#  'pantor/frankx',
#  'fkromer/awesome-robotframework',
#  'avisingh599/reward-learning-rl',
#  'visose/Robots',
#  'wangcongrobot/awesome-isaac-gym',
#  'cogsys-tuebingen/gerona',
#  'protontypes/awesome-robotic-tooling',
#  'sphero-inc/sphero.js',
#  'clvrai/furniture',
#  'rst-tu-dortmund/teb_local_planner',
#  'mattes/go-asciibot',
#  'A9T9/RPA',
#  'rpng/open_vins',
#  'Improbable-AI/walk-these-ways',
#  'OpnTec/fashionmaker',
#  'strasdat/Sophus',
#  'Ardumower/ardumower',
#  'pantor/ruckig',
#  'airalab/robonomics',
#  'awesome-photogrammetry/awesome-photogrammetry',
#  'node-webot/weixin-robot',
#  'moble/quaternion',
#  'LinuxCNC/linuxcnc',
#  'mit-acl/cadrl_ros',
#  'Dice-Developer-Team/Dice',
#  'AndrejOrsula/drl_grasping',
#  'whoenig/libMultiRobotPlanning',
#  'graspnet/graspnet-baseline',
#  'mahowik/BalancingWii',
#  'methylDragon/ros-sensor-fusion-tutorial',
#  'calcmogul/controls-engineering-in-frc',
#  'mayataka/robotoc',
#  'wpietri/sucks',
#  'zuoym15/craves.ai',
#  'EA31337/EA31337',
#  'qgallouedec/panda-gym',
#  'hku-mars/ikd-Tree',
#  'mjansen4857/pathplanner',
#  'VIS4ROB-lab/ccm_slam',
#  'yankailab/OpenKAI',
#  'visionworkbench/visionworkbench',
#  'areed1192/python-trading-robot',
#  'introlab/rtabmap',
#  'ShuoYangRobotics/Cerberus',
#  'bytedance/ibot',
#  'exAspArk/awesome-chatops',
#  'chonyy/AI-basketball-analysis',
#  'i2Nav-WHU/Wheel-INS',
#  'andyzeng/visual-pushing-grasping',
#  'lucidrains/robotic-transformer-pytorch',
#  'dheera/rosboard',
#  'ScRiPt1337/Teardroid-phprat',
#  'zz570557024/vue-mpvue-ChatRobot',
#  'appliedAI-Initiative/orb_slam_2_ros',
#  'evanw/rapt',
#  'zexiplus/WALL.E',
#  'kyprizel/testcookie-nginx-module',
#  'pirxthepilot/wtfis',
#  'facebookresearch/iSDF',
#  'aholstenson/miio',
#  'engcang/SLAM-application',
#  'lardemua/atom',
#  'DoongLi/awesome-Implicit-NeRF-SLAM',
#  'tynguyen/unsupervisedDeepHomographyRAL2018',
#  'qiayuanliao/legged_control',
#  'monperrus/crawler-user-agents',
#  'pliang279/awesome-multimodal-ml',
#  'miccol/ROS-Behavior-Tree',
#  'shekit/peeqo-robot',
#  'osrf/gazebo_models',
#  'BerkeleyAutomation/gqcnn',
#  'Derek-TH-Wang/quadruped_ctrl',
#  'caochao39/aerial_navigation_development_environment',
#  'devanhurst/ktane_voice',
#  'jazzband/django-robots',
#  'projectchrono/chrono',
#  'LiJiangnanBit/path_optimizer',
#  'ClemensElflein/xESC',
#  'Tasshack/dreame-vacuum',
#  'fkie/multimaster_fkie',
#  'APRIL-ZJU/CL-CBS',
#  'RobotLocomotion/pytorch-dense-correspondence',
#  'lich0821/WeChatRobot',
#  'nategri/nematoduino',
#  'Deeplocal/mocktailsmixer',
#  'personalrobotics/aikido',
#  'facebookresearch/habitat-lab',
#  'alajmo/mani',
#  'basnijholt/home-assistant-config',
#  'opencog/opencog',
#  'snape/RVO2-3D',
#  'semitable/robotic-warehouse',
#  'dora-rs/dora',
#  'iuiaoin/wechat-gptbot',
#  'chengxuxin/extreme-parkour',
#  'cyandterry/Like-My-GF',
#  'MISTLab/DOOR-SLAM',
#  'peract/peract',
#  'sergionr2/RacingRobot',
#  'Salman-H/pick-place-robot',
#  'PaulDanielML/MuJoCo_RL_UR5',
#  'probcomp/Gen.jl',
#  'mjl/particle_filter_demo',
#  'eclipse/repairnator',
#  'ori-mrg/robotcar-dataset-sdk',
#  'zauberzeug/nicegui',
#  'Jaeyoung-Lim/mavros_controllers',
#  'dotchen/LearningByCheating',
#  'introlab/odas',
#  'danijar/dreamerv2',
#  'chvmp/champ',
#  'pglira/simpleICP',
#  'PeterFWS/Structure-PLP-SLAM',
#  'mackorone/mms',
#  'aniskoubaa/rosgpt',
#  'garrows/browser-serialport',
#  'lucasfcosta/dotfiles',
#  'MichaelGrupp/evo',
#  'kindredresearch/SenseAct',
#  'Developer-Y/cs-video-courses',
#  'vimalabs/VIMA',
#  'AnyLoc/AnyLoc',
#  'rishabh1b/RealTimePathPlanning',
#  'cra-ros-pkg/robot_localization',
#  'OpenOCL/OpenOCL',
#  'folke/devmoji',
#  'alajmo/sake',
#  'lihuang3/ur5_ROS-Gazebo',
#  'Acmece/rl-collision-avoidance',
#  'DLR-RM/stable-baselines3',
#  'MIT-SPARK/Kimera-VIO',
#  'nonebot/nonebot',
#  'yuce/pyswip',
#  'w111liang222/lidar-slam-detection',
#  'yangyanli/PointCNN',
#  'erwincoumans/pybullet_robots',
#  'devendrachaplot/Neural-SLAM',
#  'spencer-project/spencer_people_tracking',
#  'facebookresearch/differentiable-robot-model',
#  'shannon112/awesome-ros-mobile-robot',
#  'NVIDIA-ISAAC-ROS/isaac_ros_nvblox',
#  'benct/lovelace-xiaomi-vacuum-card',
#  'chriskiehl/pyrobot',
#  '546669204/RebateBot',
#  'dfki-ric/phobos',
#  'quasilyte/roboden-game',
#  'wkentaro/morefusion',
#  'Tai-Wang/Depth-from-Motion',
#  'beardicus/awesome-plotters',
#  'dji-sdk/Onboard-SDK',
#  'pal-robotics/aruco_ros',
#  'RoboJackets/rrt',
#  'WPIRoboticsProjects/GRIP',
#  'TianhongDai/hindsight-experience-replay',
#  'nebrius/raspi',
#  'metakirby5/yorha',
#  'p-org/P',
#  'izhengfan/se2lam',
#  '26hzhang/DL-NLP-Readings',
#  'go-joe/joe',
#  'ArghyaChatterjee/gps-waypoint-based-autonomous-navigation-in-ros',
#  'Doragd/Chinese-Chatbot-PyTorch-Implementation',
#  'VitoVan/cl-dino',
#  'Unity-Technologies/ROS-TCP-Connector',
#  'AcutronicRobotics/gym-gazebo2',
#  'RobotWebTools/rclnodejs',
#  'nvidia-isaac/nvblox',
#  'star2dust/paper-simulation',
#  'ScienJus/smartqq',
#  'Simple-Robotics/proxsuite',
#  'StanfordVL/GibsonEnv',
#  'tinymovr/Tinymovr',
#  'ArduPilot/ardupilot',
#  'nickpettican/InstaBot',
#  'lavabit/robox',
#  'MISTLab/Swarm-SLAM',
#  'ScienJus/qqbot',
#  'simple-robot/simpler-robot',
#  'RoboDK/RoboDK-API',
#  'huihut/Facemoji',
#  'rdbox-intec/rdbox',
#  'stil/curl-easy',
#  'D4Vinci/elpscrk',
#  'schodet/nxt-python',
#  'HITSZ-NRSL/Dynamic-VINS',
#  'CopterExpress/clover',
#  'reiniscimurs/DRL-robot-navigation',
#  'facebookresearch/theseus',
#  'bmartin5692/bumper',
#  'aau-cns/mars_lib',
#  'ezelikman/parsel',
#  'ZJU-FAST-Lab/EGO-Planner-v2',
#  'koalazak/dorita980',
#  'keenon/nimblephysics',
#  'schroederdewitt/multiagent_mujoco',
#  'xiihoo/Books_Robot_SLAM_Navigation',
#  'Hypfer/lovelace-valetudo-map-card',
#  'jesseweisberg/moveo_ros',
#  'changh95/visual-slam-roadmap',
#  'robosoft-ai/SMACC',
#  'NVIDIA-ISAAC-ROS/isaac_ros_visual_slam',
#  'hybridgroup/gort',
#  'yybawang/laravel-ebank',
#  'google-research/ravens',
#  'pliang279/MultiBench',
#  'loco-3d/crocoddyl',
#  'MetaSLAM/AutoMerge_Docker',
#  'm2n037/awesome-mecheng',
#  'openrr/urdf-viz',
#  'aws-robotics/aws-robomaker-small-warehouse-world',
#  'microsoft/AutonomousDrivingCookbook',
#  'poppy-project/pypot',
#  'Emotional-Text-to-Speech/dl-for-emo-tts',
#  'artivis/manif',
#  'bolderflight/sbus',
#  'ros-controls/ros2_control',
#  'dusty-nv/jetson-inference',
#  'NaiboWang/EasySpider',
#  'DJTobias/Cherry-Autonomous-Racecar',
#  'vectr-ucla/direct_lidar_odometry',
#  'ugurkanates/awesome-real-world-rl',
#  'xinshuoweng/AB3DMOT',
#  'chapulina/dolly',
#  'bolderflight/invensense-imu',
#  'locusrobotics/fuse',
#  'maelstrom-cms/odin',
#  'utiasDSL/gym-pybullet-drones',
#  'NeoGeographyToolkit/StereoPipeline',
#  'cagbal/ros_people_object_detection_tensorflow',
#  'facebookresearch/ContactPose',
#  'cyberbotics/webots_ros2',
#  'gkjohnson/urdf-loaders',
#  'leggedrobotics/open3d_slam',
#  'ethz-adrl/ifopt',
#  'Gaochao-hit/LIO-SAM_based_relocalization',
#  'hasauino/rrt_exploration',
#  'devendrachaplot/Object-Goal-Navigation',
#  'Tobias-Fischer/rt_gene',
#  'MegaMek/megamek',
#  'gazebosim/gazebo-classic',
#  'lianghongzhuo/PointNetGPD',
#  'utiasDSL/safe-control-gym',
#  'MIT-SPARK/Kimera-Semantics',
#  'microsoft/AirSim-NeurIPS2019-Drone-Racing',
#  'Stable-Baselines-Team/stable-baselines3-contrib',
#  'go-skynet/LocalAI',
#  'DLR-RM/rl-baselines3-zoo',
#  'caelan/pddlstream',
#  'robocorp/rcc',
#  'awesome-vacuum/awesome-vacuum',
#  'sichkar-valentyn/Reinforcement_Learning_in_Python',
#  'caelan/pybullet-planning',
#  'vibertthio/awesome-machine-learning-art',
#  'Vincentqyw/cv-arxiv-daily',
#  'rgommezz/react-native-chatgpt',
#  'PRBonn/depth_clustering',
#  'jhu-lcsr/handeye_calib_camodocal',
#  'nickcharron/waypoint_nav',
#  'Sollimann/CleanIt',
#  'Firmament-Autopilot/FMT-Firmware',
#  'stack-of-tasks/pinocchio',
#  'aixed/WeChat-Hook',
#  'vectr-ucla/direct_lidar_inertial_odometry',
#  'OpenCyphal-Garage/libcyphal',
#  'UMich-BipedLab/LiDARTag',
#  'adham-elarabawy/open-quadruped',
#  'wil3/gymfc',
#  'sphero-inc/Sphero-iOS-SDK',
#  'wzpan/wukong-robot',
#  'Unity-Technologies/articulations-robot-demo',
#  'treflehq/trefle-api',
#  'stackgpu/Simple-GPU',
#  'yuanmingqi/rl-exploration-baselines',
#  'sail-sg/envpool',
#  'graniet/fsociety-ransomware-MrRobot',
#  'eclipse-zenoh/zenoh',
#  'omegaiota/DiffCloth',
#  'ethz-asl/polygon_coverage_planning',
#  'JuliaRobotics/RigidBodyDynamics.jl',
#  'wenbowen123/catgrasp',
#  'mathworks/MATLAB-Simulink-Challenge-Project-Hub',
#  'RLE-Foundation/rllte',
#  'OpenRL-Lab/openrl',
#  'artivis/kalmanif',
#  'tnikolla/robot-grasp-detection',
#  'google/mobly',
#  'usdot-fhwa-stol/carma-platform',
#  'bark-simulator/bark',
#  'ai-winter/ros_motion_planning',
#  'vipjeffreylee/QQrobot',
#  'OpenCyphal/libcanard',
#  'BrianPugh/belay',
#  'arouel/uadetector',
#  'zubair-irshad/CenterSnap',
#  'wenbowen123/BundleTrack',
#  'zhayujie/chatgpt-on-wechat',
#  'wenbowen123/iros20-6d-pose-tracking',
#  'WhiteWatson/wx-bot-client',
#  'UMich-BipedLab/extrinsic_lidar_camera_calibration',
#  'BAILOOL/ANMS-Codes',
#  'michaelkubina/SpotMicroESP32',
#  'navneet-nmk/pytorch-rl',
#  'Devs-Dungeon/Resources',
#  'ros-mobile-robots/diffbot',
#  'Toni-SM/skrl',
#  'alphaville/optimization-engine',
#  'osvt/TeamHelper',
#  'napframework/nap',
#  'vs4vijay/SwissArmyPi',
#  'Skythinker616/foc-wheel-legged-robot',
#  'DmitryRyumin/ICCV-2023-Papers',
#  'Sollimann/bonsai',
#  'sachink2010/AutomatedStockTrading-DeepQ-Learning',
#  'zjunlp/EasyInstruct',
#  'RajashekarRaju/compose-actors',
#  'MMehrez/MPC-and-MHE-implementation-in-MATLAB-using-Casadi',
#  'CatchZeng/dingtalk',
#  '1c7/Translate-Subtitle-File',
#  'landy22granatt/Kumpulan-Script-Termux',
#  'cirosantilli/china-dictatorship',
#  'gege-circle/home']

# %%
file = 'repo_names.json'
# Load the REPOS list from the JSON file
with open(file, 'r') as file:
    loaded_REPOS = json.load(file)
len(loaded_REPOS)
# Out:
# 677

# %%
loaded_REPOS[:10]
# Out:
# ['AtsushiSakai/PythonRobotics',
#  'kiloreux/awesome-robotics',
#  'NxRLab/ModernRobotics',
#  'mithi/robotics-coursework',
#  'onlytailei/CppRobotics',
#  'JdeRobot/RoboticsAcademy',
#  'pptacher/probabilistic_robotics',
#  'jslee02/awesome-robotics-libraries',
#  'petercorke/robotics-toolbox-python',
#  'Unity-Technologies/Unity-Robotics-Hub']

# %%
len(a.REPOS)
# Out:
# 677

# %%
process_repos = a.scrape_github_data()
process_repos
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 process_repos = a.scrape_github_data()
#       2 process_repos
#
# File ~/codeup-data-science/github_nlp_project/acquire.py:99, in scrape_github_data()
#      95 def scrape_github_data() -> List[Dict[str, str]]:
#      96     """
#      97     Loop through all of the repos and process them. Returns the processed data.
#      98     """
# ---> 99     return [process_repo(repo) for repo in REPOS]
#
# File ~/codeup-data-science/github_nlp_project/acquire.py:99, in <listcomp>(.0)
#      95 def scrape_github_data() -> List[Dict[str, str]]:
#      96     """
#      97     Loop through all of the repos and process them. Returns the processed data.
#      98     """
# ---> 99     return [process_repo(repo) for repo in REPOS]
#
# File ~/codeup-data-science/github_nlp_project/acquire.py:87, in process_repo(repo)
#      82 """
#      83 Takes a repo name like "gocodeup/codeup-setup-script" and returns a
#      84 dictionary with the language of the repo and the readme contents.
#      85 """
#      86 contents = get_repo_contents(repo)
# ---> 87 readme_contents = requests.get(get_readme_download_url(contents)).text
#      88 return {
#      89     "repo": repo,
#      90     "language": get_repo_language(repo),
#      91     "readme_contents": readme_contents,
#      92 }
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/requests/models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '': No scheme supplied. Perhaps you meant https://?
